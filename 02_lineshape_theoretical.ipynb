# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from math import pi

# %%
w_0 = 10**4

Q_c = 10**4
Q_i = 10**6
Q_L = (Q_c**(-1) + Q_i**(-1))**(-1)

dlist = np.linspace(-10,10,200)

# %%
i = 0
S_21_list = []
S_21_mag = []
S_21_ang = []
for delta in dlist:
    S_21 = 1 - ((Q_L/Q_c)/(1+(2j*Q_L*((delta)/w_0))))
    S_21_list.append(S_21)
    S_21_mag.append(abs(S_21))
    S_21_ang.append(np.angle(S_21))

# %%
fig, ax = plt.subplots(1,1,figsize=(6,6))
ax.plot(dlist, S_21_mag)
plt.xlabel("Detuning")
plt.ylabel("|S$_{2,1}$| in dB")
plt.title("S$_{2,1}$ Magnitude")

fig, ax = plt.subplots(1,1,figsize=(6,6))
ax.plot(dlist, S_21_ang)
plt.xlabel("Detuning")
plt.ylabel("Angle(S$_{2,1}$) in dB")
plt.title("S$_{2,1}$ in Phase")
# Out:
# Text(0.5, 1.0, 'S$_{2,1}$ in Phase')

# %%
re_val = []
im_val = []
def argand(complexNumber):
    y = complexNumber
    x1,y1 = [0,np.real(y)], [0, np.imag(y)]
    x2,y2 = [np.real(y), np.real(y)], [0, np.imag(y)]
    
    plt.plot(np.real(y), np.imag(y), 'ro')
    re_val.append(np.real(y))
    im_val.append(np.imag(y))
    
    for i in range(0,(len(re_val)-1)):
        x_vec = [re_val[i+1],re_val[i]]
        y_vec = [im_val[i+1],im_val[i]]
        
        plt.plot(x_vec,y_vec,'r')

# %%
fig, ax = plt.subplots(1,1,figsize=(6,6))
for delta in np.linspace(-2*pi,2*pi,100):
    S_21 = 1 - ((Q_L/Q_c)/(1+(2j*Q_L*((delta)/w_0))))
    argand(S_21)
    print(S_21)
plt.show()
# Out:
# (0.9936451517047177-0.07906671175895705j)
# (0.9933821641417055-0.08067538025653968j)
# (0.9931025469070724-0.08235038930677259j)
# (0.9928048713827269-0.08409589671472258j)
# (0.9924875525923993-0.08591641213497407j)
# (0.9921488282661808-0.08781683473357008j)
# (0.9917867345702-0.08980249573969949j)
# (0.9913990778822015-0.09187920663453374j)
# (0.9909834018618188-0.09405331385604096j)
# (0.9905369489004743-0.09633176105610593j)
# (0.9900566148314492-0.09872216013558541j)
# (0.9895388955244598-0.10123287251113129j)
# (0.9889798236663382-0.10387310234352233j)
# (0.9883748936206906-0.10665300379181823j)
# (0.9877189717389653-0.10958380476451893j)
# (0.9870061888288506-0.11267795013508189j)
# (0.9862298106272372-0.11594926799579126j)
# (0.9853820810117433-0.11941316326744994j)
# (0.984454031232089-0.12308684389538774j)
# (0.9834352465338448-0.12698958598522844j)
# (0.9823135790209986-0.13114304561414963j)
# (0.9810747922354819-0.13557162675460413j)
# (0.9797021184048365-0.14030291683784646j)
# (0.9781757031744369-0.14536820404354264j)
# (0.976471904254608-0.15080309351258023j)
# (0.9745623988446355-0.1566482434170372j)
# (0.9724130385848185-0.16295024622020454j)
# (0.9699823681261962-0.1697626854597744j)
# (0.9672196911994246-0.17714740371407467j)
# (0.9640625217918225-0.18517602234709463j)
